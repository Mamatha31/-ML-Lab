# %% [markdown]
# ## Multiple Linear Regression
#
# Now you know how to build a model with one X (independent variable) and Y (dependent variable). But what if you have three feature variables, or may be 10 or 100? By using multiple linear regression, you can build models between a dependent variable and many independent variables.
#
# Dataset - advertising.csv
#
# Independent variables - TV Ad Expenses, Radio Ad Expenses, Newspaper Ad Expenses
#
# Dependent variable - Sales

# %%
#1 Import necessery libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#2 Import the dataset (advertising.csv) and look at the top five rows
df = pd.read_csv('advertising.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7188812e3ad7> in <module>
#       1 #2 Import the dataset (advertising.csv) and look at the top five rows
# ----> 2 df = pd.read_csv('advertising.csv')
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'advertising.csv'

# %%
#3 Look at the bottom five rows
df.tail()

# %%
#4 Check the shape of the DataFrame (rows, columns)
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c70037beacfc> in <module>
#       1 #4 Check the shape of the DataFrame (rows, columns)
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %%
#5 Look at the data types of the columns
df['TV'].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c55f2b683ac3> in <module>
#       1 #5 Look at the data types of the columns
# ----> 2 df['TV'].dtype
#
# NameError: name 'df' is not defined

# %%
#6 Look at the summary statistics
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ff67c3a0ffb6> in <module>
#       1 #6 Look at the summary statistics
# ----> 2 df.describe()
#
# NameError: name 'df' is not defined

# %%
#7 Do a pairplot of the variables
sns.pairplot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-070372be8015> in <module>
#       1 #7 Do a pairplot of the variables
# ----> 2 sns.pairplot(df)
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
#8 Visualise the relationship between the independent variables and the depenedent variable using scatterplots
plt.scatter(df.iloc[:,0], df.iloc[:,3], color = 'red')
plt.scatter(df.iloc[:,1], df.iloc[:,3], color = 'blue')
plt.scatter(df.iloc[:,2], df.iloc[:,3], color = 'green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1af744684c96> in <module>
#       1 #8 Visualise the relationship between the independent variables and the depenedent variable using scatterplots
# ----> 2 plt.scatter(df.iloc[:,0], df.iloc[:,3], color = 'red')
#       3 plt.scatter(df.iloc[:,1], df.iloc[:,3], color = 'blue')
#       4 plt.scatter(df.iloc[:,2], df.iloc[:,3], color = 'green')
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
#9 Prepare  X (independent variables) and y (dependent variable)
X = df.iloc[:,:-1]
y = df.iloc[:,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9bb95911c031> in <module>
#       1 #9 Prepare  X (independent variables) and y (dependent variable)
# ----> 2 X = df.iloc[:,:-1]
#       3 y = df.iloc[:,-1]
#
# NameError: name 'df' is not defined

# %%
#10 Split Data into Training and Testing Sets (70%-Train 30%-Test) - X_train, y_train, X_test, y_test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f68f990aa851> in <module>
#       1 #10 Split Data into Training and Testing Sets (70%-Train 30%-Test) - X_train, y_train, X_test, y_test
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)
#
# NameError: name 'X' is not defined

# %%
#11 Fitting Multiple Linear Regression to the Training
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4b8836fe5010> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3 lr = LinearRegression()
# ----> 4 lr.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
#12 Predict on the train set and calculate the error = y_pred - y_train
# Residual plot - plot y_pred in x axis and errors in y axis
y_pred = lr.predict(X_train)
error = y_pred - y_train
sns.residplot(y_pred, error)
plt.show()

# %%
#13 Predic on the test set
y_pred = lr.predict(X_test)
error = y_pred - y_test
sns.residplot(y_pred, error)
plt.show()

# %%
#14 Print Mean Squared Error and R Squared Value
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 3.867852396251159

# %% [markdown]
# ## Backward elimination

# %%
#15 Build the optimal model using backward elimination

# %% [markdown]
# ## Housing Case Study
# Problem Statement:
#
# Consider a real estate company that has a dataset containing the prices of properties in the Delhi region. It wishes to use the data to optimise the sale prices of the properties based on important factors such as area, bedrooms, parking, etc.
#
# Essentially, the company wants —
#
#
# - To identify the variables affecting house prices, e.g. area, number of rooms, bathrooms, etc.
#
# - To create a linear model that quantitatively relates house prices with variables such as number of rooms, area, number of bathrooms, etc.
#
# - To know the accuracy of the model, i.e. how well these variables can predict house prices.

# %%
#16Import the dataset (Housing.csv) and look at the top five rows
df2 = pd.read_csv('Housing.csv')

# %%
#17 Look at the bottom five rows
df2.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#18 Check the shape of the DataFrame (rows, columns)
df2.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
#19 Look at the data types of the columns
df2['price'].dtype
# Out:
# dtype('int64')

# %%
#20 Look at the summary statistics
df2.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#21 Prepare  X (independent variables) and y (dependent variable)
X = df2.iloc[:,1:]
X
y = df2.iloc[:,0]
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
#22 Encoding categorical data in X
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X.iloc[:,4] = le.fit_transform(X.iloc[:,4])
X.iloc[:,5] = le.fit_transform(X.iloc[:,5])
X.iloc[:,6] = le.fit_transform(X.iloc[:,6])
X.iloc[:,7] = le.fit_transform(X.iloc[:,7])
X.iloc[:,8] = le.fit_transform(X.iloc[:,8])
X.iloc[:,10] = le.fit_transform(X.iloc[:,10])
X.iloc[:,11] = le.fit_transform(X.iloc[:,11])

# %%
#23 Avoiding the Dummy Variable Trap
X = X.get_dummies(X,colums=['furnishingstatus'], drop_first=True)
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0     232         4          2        3         1          0         0
# 1     260         4          4        4         1          0         0
# 2     268         3          2        2         1          0         1
# 3     237         4          2        2         1          0         1
# 4     232         4          1        2         1          1         1
# 5     237         3          3        1         1          0         1
# 6     256         4          3        4         1          0         0
# 7     283         5          3        2         1          0         0
# 8     249         4          1        2         1          1         1
# 9     172         3          2        4         1          1         0
# 10    281         3          1        2         1          0         1
# 11    183         4          3        2         1          1         1
# 12    205         4          2        2         1          0         0
# 13     64         4          2        2         1          0         0
# 14    243         3          2        2         1          0         0
# 15    183         4          1        2         1          0         1
# 16    206         4          2        2         1          1         1
# 17    254         3          2        4         1          0         0
# 18    130         3          2        2         1          1         0
# 19    198         3          2        2         1          0         0
# 20    118         3          1        2         1          0         1
# 21    224         3          2        1         1          1         1
# 22    247         3          1        1         1          1         1
# 23    129         3          2        2         1          1         1
# 24    257         3          2        2         1          0         0
# 25    204         4          2        2         1          1         1
# 26    183         3          2        4         1          1         1
# 27    258         3          1        1         1          0         0
# 28    244         5          2        2         1          0         1
# 29    166         4          2        2         1          0         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 515    51         3          1        2         1          0         1
# 516    52         2          1        1         0          1         0
# 517    39         2          1        1         1          0         0
# 518    64         2          1        1         1          1         0
# 519   142         2          1        2         1          0         0
# 520   241         2          1        1         1          0         0
# 521    74         2          1        1         0          0         0
# 522    17         3          1        2         1          0         0
# 523    27         4          2        2         1          0         0
# 524    53         2          1        1         1          0         0
# 525    75         2          1        1         1          0         0
# 526    49         2          1        1         1          0         0
# 527     2         2          1        1         0          0         1
# 528    97         1          1        1         0          0         0
# 529    97         3          1        2         1          0         1
# 530     4         3          1        1         0          0         0
# 531   160         3          1        1         0          0         0
# 532    39         2          1        1         0          0         0
# 533    15         3          1        2         1          0         0
# 534    39         4          1        2         1          0         0
# 535    57         2          1        1         1          0         0
# 536    60         5          1        2         0          0         0
# 537     1         3          1        2         1          0         0
# 538    76         2          1        1         1          0         0
# 539    38         2          1        1         0          0         0
# 540    39         2          1        1         1          0         1
# 541    15         3          1        1         0          0         0
# 542    72         2          1        1         1          0         0
# 543    35         3          1        1         0          0         0
# 544    90         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                  0                1        2         1                 0
# 1                  0                1        3         0                 0
# 2                  0                0        2         1                 1
# 3                  0                1        3         1                 0
# 4                  0                1        2         0                 0
# 5                  0                1        2         1                 1
# 6                  0                1        2         1                 1
# 7                  0                0        0         0                 2
# 8                  0                1        2         1                 0
# 9                  0                1        1         1                 2
# 10                 0                1        2         1                 0
# 11                 1                0        2         0                 1
# 12                 0                1        1         1                 1
# 13                 1                0        2         0                 0
# 14                 0                0        0         1                 1
# 15                 0                0        2         0                 1
# 16                 0                1        1         1                 2
# 17                 0                1        2         0                 0
# 18                 0                1        2         0                 0
# 19                 0                1        1         1                 1
# 20                 1                0        2         0                 1
# 21                 0                1        2         0                 2
# 22                 0                1        1         0                 0
# 23                 0                1        1         0                 0
# 24                 0                1        2         0                 0
# 25                 0                1        2         1                 0
# 26                 0                1        0         1                 1
# 27                 0                0        1         0                 1
# 28                 1                0        2         0                 2
# 29                 0                1        1         1                 1
# ..               ...              ...      ...       ...               ...
# 515                0                0        0         0                 2
# 516                0                0        1         0                 2
# 517                0                0        1         0                 2
# 518                0                0        0         0                 2
# 519                0                0        0         0                 2
# 520                0                0        0         0                 2
# 521                0                0        0         0                 2
# 522                0                0        0         0                 0
# 523                0                0        0         0                 0
# 524                0                0        0         0                 2
# 525                0                0        0         0                 2
# 526                0                0        0         0                 2
# 527                0                0        0         0                 1
# 528                0                0        0         0                 2
# 529                0                0        0         0                 2
# 530                1                0        0         0                 2
# 531                0                1        0         1                 2
# 532                0                0        0         0                 2
# 533                0                0        0         0                 2
# 534                0                0        0         0                 2
# 535                0                0        1         0                 2
# 536                0                0        0         0                 2
# 537                0                0        0         0                 2
# 538                0                0        0         0                 2
# 539                0                0        1         0                 2
# 540                0                0        2         0                 2
# 541                0                0        0         0                 1
# 542                0                0        0         0                 2
# 543                0                0        0         0                 0
# 544                0                0        0         0                 2
#
# [545 rows x 12 columns]

# %%
#24 Look at the top 5 rows after preprocessing
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0   232         4          2        3         1          0         0
# 1   260         4          4        4         1          0         0
# 2   268         3          2        2         1          0         1
# 3   237         4          2        2         1          0         1
# 4   232         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                1        2         1                 0
# 1                0                1        3         0                 0
# 2                0                0        2         1                 1
# 3                0                1        3         1                 0
# 4                0                1        2         0                 0

# %%
#25 Apply feature scaling on numerical variables
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
#26 Split Data into Training and Testing Sets (70%-Train 30%-Test) - X_train, y_train, X_test, y_test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)

# %% [markdown]
# ## Backward elimination

# %%
#27 #15 Build the optimal model using backward elimination
import statsmodels.formula.api as smf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e8749453d403> in <module>()
#       1 #27 #15 Build the optimal model using backward elimination
# ----> 2 import statsmodels.formula.api as smf
#       3
#       4
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/__init__.py in <module>()
#       8
#       9 from warnings import simplefilter
# ---> 10 from statsmodels.tools.sm_exceptions import (ConvergenceWarning, CacheWriteWarning,
#      11                                              IterationLimitWarning, InvalidTestWarning)
#      12
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/tools/__init__.py in <module>()
# ----> 1 from .tools import add_constant, categorical
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py in <module>()
#       3 '''
#       4 from statsmodels.compat.python import reduce, lzip, lmap, asstr2, range, long
# ----> 5 import numpy as np
#       6 import numpy.lib.recfunctions as nprf
#       7 import numpy.linalg as L
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/__init__.py in <module>()
#     140     from . import _distributor_init
#     141
# --> 142     from . import core
#     143     from .core import *
#     144     from . import compat
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/__init__.py in <module>()
#      65         "numpy in {}. One method of fixing this is to repeatedly uninstall "
#      66         "numpy until none is found, then reinstall this version.")
# ---> 67     raise ImportError(msg.format(path))
#      68
#      69 from . import numerictypes as nt
#
# ImportError: Something is wrong with the numpy installation. While importing we detected an older version of numpy in ['/home/laxmi/anaconda3/lib/python3.6/site-packages/numpy']. One method of fixing this is to repeatedly uninstall numpy until none is found, then reinstall this version.
